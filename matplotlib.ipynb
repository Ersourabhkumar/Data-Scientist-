# %% [markdown]
# **matplotlib learning**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=[1,2,3,4]
y=[10,20,15,35]

plt.plot(x,y)
plt.show()

# %%
x=["mon","tue","wed","Thu","fri"]
y=[2,45,6,8,5]
plt.plot(x,y)
plt.title("bakery sales this week")
plt.xlabel("days")
plt.ylabel("sales per day")
plt.show()

# %%
# plt.plot(x,y, color="color name",linestyle="line_name",linewidth="value",maker="marker symbol",label="label anme")

# %%
# months=[1,2,3,4]
# sales=[1000,2300,2000,1800]

# plt.plot(months,sales, color="red",linestyle="--",linewidth="2",maker="O",label="2025 sales data")
# plt.show()

# %%
# plt.bar(x,height,color="",width="",label="")
# plt.plot(values,label="lable_list",colors="",autopct="%.2f")
#plt.hist(data,bins=number_of_bins,color="colorname",edgecolor="black")

# %%
#plt.scatter(x,y,color="",marker="",label="")

# %%
# x=[1,2,3,4]
# y=[10,20,30,25]
# # fig,ax=plt.subplot(nrows,ncols,figsize=(width,height))
# fig,ax=plt.subplot(1,2, figsize = (10,5))

# ax[0].plot(x,y)
# ax[0].set_title("line plot")

# ax[1].bar(x,y)
# ax[1].set_title("bar chart")
